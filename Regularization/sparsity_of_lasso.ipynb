# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import make_regression
from sklearn.linear_model import Lasso

# %%
X, y, coef = make_regression(n_samples = 100,
                             n_features = 10,
                             n_informative = 3,
                             noise = 10,
                             coef = True,
                             random_state = 42)

# %%
lasso = Lasso(alpha = 1.0)
lasso.fit(X, y)
# Out:
# Lasso()

# %%
lasso.coef_
# Out:
# array([ 1.55824270e+01,  0.00000000e+00,  0.00000000e+00,  6.22901506e+01,
#         7.09460749e-01, -0.00000000e+00, -5.00090493e-02,  8.39802773e+00,
#         0.00000000e+00, -1.48955032e-01])

# %%
plt.figure(figsize = (10, 6))
plt.bar(range(len(lasso.coef_)), lasso.coef_)
plt.title("Lasso Coefficients - Some are Exactly Zero")
plt.xlabel("Feature Index")
plt.ylabel("Coefficient Value")
plt.axhline(0, color = 'black', linestyle = '--')
plt.show()
